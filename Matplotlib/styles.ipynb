# %% [markdown]
# ## スタイル

# %%
import matplotlib
import matplotlib.style

matplotlib.style.use("ggplot")  # スタイルを指定

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# 線の色を名前で指定
ax.plot([1, 3], [3, 1], label="aqua", color="aqua")
# 16進数のRGBで指定
ax.plot([1, 3], [1, 3], label="#0000FF", color="#0000FF")
# RGBAをfloatで指定
ax.plot([1, 3], [2, 2], label="(0.1, 0.2, 0.5, 0.3)",
        color=(0.1, 0.2, 0.5, 0.3))
ax.legend()  # 凡例を表示

plt.show()

# %%
fig, ax = plt.subplots()

ax.bar([1], [3], color="aqua")  # 塗りつぶしの色を指定
# 塗りつぶしの色と枠線の色を指定
ax.bar([2], [4], color="aqua", edgecolor="black")

plt.show()

# %% [markdown]
# ### 線のスタイル

# %%
fig, ax = plt.subplots()

# 5.5ポイントの幅の線で描画
ax.plot([1, 3], [3, 1], linewidth=5.5, label="5.5")
# 10ポイントの幅の線で描画
ax.plot([1, 3], [1, 3], linewidth=10, label="10")
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

# 破線で描画
ax.plot([1, 3], [3, 1], linestyle="--", label="dashed", linewidth=5.5, color="black")
# 一点鎖線で描画
ax.plot([1, 3], [1, 3], linestyle="-.", label="dashdot", linewidth=10, color="black")
# 点線で描画
ax.plot([1, 3], [2, 2], linestyle=":", label="dotted", linewidth=10, color="black")
ax.legend()

plt.show()

# %% [markdown]
# ### フォント

# %%
fig, ax = plt.subplots()

ax.set_xlabel("xlabel", family="fantasy", size=20,
              weight="bold")
ax.set_ylabel("ylabel", family="cursive", size=40,
              weight="light")
ax.set_title("graph title", family="monospace",
             size=25, weight="heavy")

plt.show()

# %% [markdown]
# ### テキスト描画

# %%
# フォントのスタイルを辞書で定義
fontdict = {
    "family": "fantasy",
    "size": 20,
    "weight": "normal",
}

fig, ax = plt.subplots()

# 辞書形式でフォントのスタイルを指定
ax.set_xlabel("xlabel", fontdict=fontdict)
ax.set_ylabel("ylabel", fontdict=fontdict)
# 個別指定したsizeで上書き可能
ax.set_title("graph title", fontdict=fontdict, size=40)

plt.show()

# %%
# グラフのスタイルにclassicを指定
matplotlib.style.use("classic")

fig, ax = plt.subplots()
ax.plot([1, 2])

plt.show()
