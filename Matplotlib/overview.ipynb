# %% [markdown]
# ## Matplotlibの概要

# %%
import matplotlib.pyplot as plt
import matplotlib.style

# ggplotスタイルを指定
matplotlib.style.use("ggplot")

# %%
# データを用意
x = [1, 2, 3]
y = [2, 4, 9]

plt.plot(x, y)  # 折れ線グラフを描画
plt.title("pyplot interface")  # グラフにタイトルを設定

plt.show() # グラフを表示

# %% [markdown]
# ### オブジェクト指向スタイル

# %%
# データを用意
x = [1, 2, 3]
y = [2, 4, 9]

# 描画オブジェクト(fig)とサブプロット(ax)を生成
fig, ax = plt.subplots()

ax.plot(x, y)  # 折れ線グラフを描画
ax.set_title("object-oriented interface")  # タイトルを設定

plt.show()  # グラフを表示
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 y = [2, 4, 9]
#       5 # 描画オブジェクト(fig)とサブプロット(ax)を生成
# ----> 6 fig, ax = plt.subplots()
#       8 ax.plot(x, y)  # 折れ線グラフを描画
#       9 ax.set_title("object-oriented interface")  # タイトルを設定
#
# NameError: name 'plt' is not defined
